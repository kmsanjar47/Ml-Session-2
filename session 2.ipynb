# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Bank Data.csv")

# %%
df.head(5)
# Out:
#        ID Customer_ID      Month             Name  Age          SSN  \
# 0  0x160a   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265
# 1  0x160b   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265
# 2  0x160c   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265
# 3  0x160d   CUS_0xd40   December    Aaron Maashoh  24_  821-00-0265
# 4  0x1616  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0  Scientist      19114.12            1824.843333                  3  ...
# 1  Scientist      19114.12            1824.843333                  3  ...
# 2  Scientist      19114.12            1824.843333                  3  ...
# 3  Scientist      19114.12                    NaN                  3  ...
# 4    _______      34847.84            3037.986667                  2  ...
#
#    Num_Credit_Inquiries  Credit_Mix Outstanding_Debt Credit_Utilization_Ratio  \
# ...

# %%
df.shape #26 Features, 1 class(Payment of min amount)
# Out:
# (50000, 27)

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Null Handling

# %%
df.isna().sum()
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                        5015
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary       7498
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                5704
# Delay_from_due_date            0
# Num_of_Delayed_Payment      3498
# Changed_Credit_Limit           0
# Num_Credit_Inquiries        1035
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          4470
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     2271
# Payment_Behaviour              0
# Monthly_Balance              562
# dtype: int64

# %%
# Row deletion
# Imputation

# %%
# Removing ID, CustomerID, Name

# %%
df2 = df.drop(["ID","Customer_ID", "Name", "Month","Age", "Occupation", "SSN"],axis = 1) ## axis = 0: row, axis = 1:column

# %%
df2.head(5)
# Out:
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0      19114.12            1824.843333                  3                4
# 1      19114.12            1824.843333                  3                4
# 2      19114.12            1824.843333                  3                4
# 3      19114.12                    NaN                  3                4
# 4      34847.84            3037.986667                  2                4
#
#    Interest_Rate Num_of_Loan  \
# 0              3           4
# 1              3           4
# 2              3           4
# 3              3           4
# 4              6           1
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 2  Auto Loan, Credit-Builder Loan, Personal Loan,...                   -1
# ...

# %%
df2.dtypes
# Out:
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# Monthly_Balance              object
# dtype: object

# %%
df2.nunique()
# Out:
# Annual_Income               16121
# Monthly_Inhand_Salary       12793
# Num_Bank_Accounts             540
# Num_Credit_Card               819
# Interest_Rate                 945
# Num_of_Loan                   263
# Type_of_Loan                 6260
# Delay_from_due_date            73
# Num_of_Delayed_Payment        443
# Changed_Credit_Limit         3927
# Num_Credit_Inquiries          750
# Credit_Mix                      4
# Outstanding_Debt            12685
# Credit_Utilization_Ratio    50000
# Credit_History_Age            399
# Payment_of_Min_Amount           3
# Total_EMI_per_month         13144
# Amount_invested_monthly     45450
# Payment_Behaviour               7
# Monthly_Balance             49433
# dtype: int64

# %%
df2.isna().sum()
# Out:
# Annual_Income                  0
# Monthly_Inhand_Salary       7498
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                5704
# Delay_from_due_date            0
# Num_of_Delayed_Payment      3498
# Changed_Credit_Limit           0
# Num_Credit_Inquiries        1035
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          4470
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     2271
# Payment_Behaviour              0
# Monthly_Balance              562
# dtype: int64

# %%
df2.dtypes
# Out:
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# Monthly_Balance              object
# dtype: object

# %%
# df2["Monthly_Inhand_Salary"].fillna(value = df2["Monthly_Inhand_Salary"].mean())

#Fillna

#Mean - avg
#Median - middle number (odd, even)
#Mode - max(value)

#Categorical values, Quantitative values

#For Quantitative values - Mean - 
#For Categorical Values - Mode

# listiloc[2:0,2:0]
# dataframe["column_name"].fillna(value = dataframe["column_name"].mean()) #Quantititive
# dataframe["column_name"].fillna(value = dataframe["column_name"].mode().iloc[0]) #Categorical

# %%
#Monthly_Inhand_Salary, Type_of_Loan, Num_of_Delayed_Payment, Num_Credit_Inquiries, Credit_History_Age, Amount_invested_monthly, Monthly_Balance

# df2["Monthly_Inhand_Salary"].fillna(value = df2["Monthly_Inhand_Salary"].mean(), inplace = True) # Inplace directly manupulates data

# Quantititive : null(isna().sum()) > 0, no of unique values < 10,   

for col_name in df2.columns:
    # print(col_name)
    col_data = df2[col_name]
    
    if col_data.isna().sum() > 0 and col_data.nunique() > 10 and col_data.dtype != "object": # Quantititive
        col_data.fillna(value = col_data.mean(), inplace = True)
    elif col_data.isna().sum() > 0 and col_data.nunique() < 10 and col_data.dtype != "object": # Categorical
        col_data.fillna(value = col_data.mode().iloc[0], inplace = True)

# %%
df2.isna().sum()
# Out:
# Annual_Income                  0
# Monthly_Inhand_Salary          0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                5704
# Delay_from_due_date            0
# Num_of_Delayed_Payment      3498
# Changed_Credit_Limit           0
# Num_Credit_Inquiries           0
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          4470
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     2271
# Payment_Behaviour              0
# Monthly_Balance              562
# dtype: int64

# %% [markdown]
# ## Encoding

# %%
df2.head(2)
# Out:
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0      19114.12            1824.843333                  3                4
# 1      19114.12            1824.843333                  3                4
#
#    Interest_Rate Num_of_Loan  \
# 0              3           4
# 1              3           4
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                    3
#
#   Num_of_Delayed_Payment Changed_Credit_Limit  Num_Credit_Inquiries  \
# 0                      7                11.27                2022.0
# 1                      9                13.27                   4.0
#
#   Credit_Mix Outstanding_Debt  Credit_Utilization_Ratio  \
# 0       Good           809.98                 35.030402
# 1       Good           809.98                 33.053114
#
# ...

# %%
df2["Type_of_Loan"]
# Out:
# 0        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 1        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 2        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 3        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 4                                      Credit-Builder Loan
#                                ...
# 49995    Personal Loan, Auto Loan, Mortgage Loan, Stude...
# 49996                          Auto Loan, and Student Loan
# 49997                          Auto Loan, and Student Loan
# 49998                          Auto Loan, and Student Loan
# 49999                          Auto Loan, and Student Loan
# Name: Type_of_Loan, Length: 50000, dtype: object

# %%
df2.nunique()
# Out:
# Annual_Income               16121
# Monthly_Inhand_Salary       12794
# Num_Bank_Accounts             540
# Num_Credit_Card               819
# Interest_Rate                 945
# Num_of_Loan                   263
# Type_of_Loan                 6260
# Delay_from_due_date            73
# Num_of_Delayed_Payment        443
# Changed_Credit_Limit         3927
# Num_Credit_Inquiries          751
# Credit_Mix                      4
# Outstanding_Debt            12685
# Credit_Utilization_Ratio    50000
# Credit_History_Age            399
# Payment_of_Min_Amount           3
# Total_EMI_per_month         13144
# Amount_invested_monthly     45450
# Payment_Behaviour               7
# Monthly_Balance             49433
# dtype: int64

# %%
# One hot encoder - 
# Label Encoder - 
# Ordinal Encoder -

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
encoder.fit_transform(df2["Type_of_Loan"])
# Out:
# array([128, 128, 128, ..., 683, 683, 683])
